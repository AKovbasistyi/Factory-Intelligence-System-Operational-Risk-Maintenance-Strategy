# %%
import pandas as pd
from sqlalchemy import create_engine

connection_string = 'mssql+pyodbc://localhost\\SQLEXPRESS/Master?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes'
engine = create_engine(connection_string)

# %%
# Load CSV
Maintenance_Strategy = pd.read_csv('Operational Risk & Maintenance Strategy.csv')
Maintenance_Strategy.head()
# Out:
#    UDI Product_ID Type  Air_temperature_K  Process_temperature_K  \
# 0    1     M14860    M              298.1                  308.6
# 1    2     L47181    L              298.2                  308.7
# 2    3     L47182    L              298.1                  308.5
# 3    4     L47183    L              298.2                  308.6
# 4    5     L47184    L              298.2                  308.7
#
#    Rotational_speed_rpm  Torque_Nm  Tool_wear_min  Machine_failure  TWF  HDF  \
# 0                  1551       42.8              0                0    0    0
# 1                  1408       46.3              3                0    0    0
# 2                  1498       49.4              5                0    0    0
# 3                  1433       39.5              7                0    0    0
# 4                  1408       40.0              9                0    0    0
#
#    PWF  OSF  RNF
# 0    0    0    0
# 1    0    0    0
# 2    0    0    0
# 3    0    0    0
# 4    0    0    0

# %%
# CSV headers to clean SQL column names
Maintenance_Strategy.columns = [
    'UDI', 'Product_ID', 'Type', 'Air_temperature_K', 
    'Process_temperature_K', 'Rotational_speed_rpm', 'Torque_Nm', 
    'Tool_wear_min', 'Machine_failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF'
]
# Out:
# 17

# %%
#Push to SQL
Maintenance_Strategy.to_sql('Maintenance_Strategy', engine, if_exists='replace', index=False)
# Out:
# Table reloaded with cleaned column names!
